# %% [markdown]
# NAME: OKPARAJI STANLEY UDODIRI
#
# EMAIL: okparajistanley9@gmail
#
# HAMOYE ID: 14548b1b7c81f000

# %%
# import libraries and dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

dataset = pd.read_csv('energydata_complete.csv')
display(dataset.head())
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
dataset.shape
# Out:
# (19735, 29)

# %%
dataset.describe().T
# Out:
#                count        mean         std         min         25%  \
# Appliances   19735.0   97.694958  102.524891   10.000000   50.000000
# lights       19735.0    3.801875    7.935988    0.000000    0.000000
# T1           19735.0   21.686571    1.606066   16.790000   20.760000
# RH_1         19735.0   40.259739    3.979299   27.023333   37.333333
# T2           19735.0   20.341219    2.192974   16.100000   18.790000
# RH_2         19735.0   40.420420    4.069813   20.463333   37.900000
# T3           19735.0   22.267611    2.006111   17.200000   20.790000
# RH_3         19735.0   39.242500    3.254576   28.766667   36.900000
# T4           19735.0   20.855335    2.042884   15.100000   19.530000
# RH_4         19735.0   39.026904    4.341321   27.660000   35.530000
# T5           19735.0   19.592106    1.844623   15.330000   18.277500
# RH_5         19735.0   50.949283    9.022034   29.815000   45.400000
# T6           19735.0    7.910939    6.090347   -6.065000    3.626667
# ...

# %%
# checking if there is any null value
display(dataset.isnull().sum())
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %% [markdown]
# ### Question 12

# %%
# import train_test_split and linear regression model for splitting the dataset and training our model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
X = dataset[['T2']]
y = dataset['T6']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=2)

linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
pred_values = linear_reg.predict(X_test)

# %%
# R-Squared Score
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, pred_values)
round(r2_score, 2)
# Out:
# 0.65

# %% [markdown]
# ### Question 13

# %%
df_1 = dataset.drop(columns = ['date', 'lights'], axis=1)

# Normalization
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()

norm_data = pd.DataFrame(Scaler.fit_transform(df_1), columns=df_1.columns)

# %%
x_1 = norm_data.drop(columns=['Appliances'])
y_1 = norm_data['Appliances']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_1, y_1, test_size=0.3, random_state=42)

# %%
# Regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
predicted_values = linear_model.predict(x_test)

# %%
# MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.05

# %% [markdown]
# ### Question 14

# %%
# to get RSS
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %% [markdown]
# ### Question 15

# %%
# to get Root Mean Squared Error i.e RMSE
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# ### Question 16

# %%
# to get the R-Squared or also called Coefficient of Determination
from sklearn.metrics import r2_score
r2 = r2_score(y_test, predicted_values)
round(r2, 2)
# Out:
# 0.15

# %% [markdown]
# ### Question 17

# %%
# Feature Weights from linear model

def get_weights_df(model, feat, col_name):
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df
    
linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv2             0.000770
# 11          rv1             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
# to get the the lowest and highest weights respectively
display(linear_model_weights.nsmallest(n=1,columns='Linear_Model_Weight'))
display(linear_model_weights.nlargest(n=1,columns='Linear_Model_Weight'))
# Out:
#   Features  Linear_Model_Weight
# 0     RH_2            -0.456698
#    Features  Linear_Model_Weight
# 25     RH_1             0.553547

# %% [markdown]
# ### Question 18

# %%
# to train a Ridge Regression

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)

Pred_1 = ridge_reg.predict(x_test)

# %%
# RMSE when evaluated
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, Pred_1))
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# ### Question 19

# %%
# LASSO Regression
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)

Pred_2 = lasso_reg.predict(x_test)

print(np.sum(lasso_reg.coef_ != 0))
# Out:
# 4

# %% [markdown]
# ### Question 20

# %%
# new RMSE with LASSO Regression
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, Pred_2))
print(round(rmse, 3))
# Out:
# 0.094
